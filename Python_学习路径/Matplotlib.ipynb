# %% [markdown]
# ## Matplotlib

# %%
# This line configures matplotlib to show figures embbed in the notebook
# instead of showing it in a new window
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Example

# %% [markdown]
# A simple figure

# %%
x = np.linspace(0,5,10)
y = x ** 2

# %%
plt.figure()
plt.plot(x,y,'r')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Quadratic Graph")
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(x,y,'g*-')

# %% [markdown]
# ### Matplotlib object-oriented API

# %%
fig = plt.figure()
ax = fig.add_axes([0.1,0.1,0.8,0.8]) # left, bottom, width, height
ax.plot(x,y,'r')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title')

# %% [markdown]
# ### add_axes

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8]) # main axes
ax2 = fig.add_axes([0.2,0.5,0.4,0.3]) # inset axes

# main figure
ax1.plot(x,y,'r')

# inset
ax2.plot(y,x,'g')

# %% [markdown]
# ### add_subplots

# %%
fig, ax = plt.subplots()
ax.plot(x,y,'r')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('quadratic plot')

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2)
for axes in ax:
    axes.plot(x,y,'r')

# %%
# tight_layout to remove non-overlapping space
fig, ax = plt.subplots(nrows = 1, ncols = 2)
for axes in ax:
    axes.plot(x,y,'r')
fig.tight_layout()

# %% [markdown]
# ### Figure size, aspect ratio and DPI

# %%
fig = plt.figure(figsize = (8,4), dpi = 100)

# %%
fig, ax = plt.subplots(figsize = (12,3), dpi = 100)
ax.plot(x,y,'r')
ax.set_title("title")

# %% [markdown]
# ### saving figures

# %%
fig.savefig('filename.png')

# %% [markdown]
# ### legends, labels and titles

# %%
# legends
fig, ax = plt.subplots(figsize = (12,3))
ax.plot(x, x ** 2, label = "curve1")
ax.plot(x, x ** 3, label = 'curve2')
ax.legend()

# %% [markdown]
# The `legend` function takes an optional keyword argument `loc` that can be used to specify where in the figure the legend is to be drawn. The allowed values of `loc` are numerical codes for the various palces the the legend can be drawn

# %%
ax.legend(loc=0) # let matplotlib decide the optimal location
ax.legend(loc=1) # upper right corner
ax.legend(loc=2) # upper left corner
ax.legend(loc=3) # lower left corner
ax.legend(loc=4) # lower right corner
# .. many more options are available

# %%
fig, ax = plt.subplots()
ax.plot(x, x ** 2, label = "y = x**2")
ax.plot(x, x ** 3, label = "y = x**3")
ax.legend(loc = 0) # upper left corner

# %% [markdown]
# ### formatting text: LaTeX, fontsize, font family

# %%
fig, ax = plt.subplots()
ax.plot(x, x ** 2, label = r"$y = \alpha^2$")
ax.plot(x, x ** 3, label = r"$y = \alpha^3$")
ax.legend(loc = 0) # upper left corner
ax.set_xlabel(r'$\alpha$', fontsize = 18)
ax.set_ylabel(r'$y$', fontsize = 18)
ax.set_title('title')

# %%
# Update the matplotlib configuration parameters
plt.rcParams.update({'font.size': 18, 'font.family': 'STIXGeneral', 'mathtext.fontset': 'stix'})

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, label=r"$y = \alpha^2$")
ax.plot(x, x**3, label=r"$y = \alpha^3$")
ax.legend(loc=2) # upper left corner
ax.set_xlabel(r'$\alpha$')
ax.set_ylabel(r'$y$')
ax.set_title('title');

# %%
# restore
plt.rcParams.update({'font.size': 12, 'font.family': 'sans', 'text.usetex': False})

# %% [markdown]
# ### Setting colors, linewidth, linetypes

# %%
fig, ax = plt.subplots(dpi = 100)
ax.plot(x, x + 1, color = "red", alpha = 0.5) # half-transparent red
ax.plot(x, x + 2, color = '#1155dd') # RGB hex code for blue
ax.plot(x, x + 3, color = '#15cc55') # RGB hex code for green

# %% [markdown]
# #### Line and marker styles

# %%
fig, ax = plt.subplots(figsize = (12,6))

# linewidth/lw
ax.plot(x, x + 1, color = "blue", linewidth = 1)
ax.plot(x, x + 2, color = "blue", lw = 2)
ax.plot(x, x + 3, color = "blue", linewidth = 3)
ax.plot(x, x + 4, color = "blue", lw = 4)

# linestyle/ls : '-','--','-.',':','steps'
ax.plot(x, x + 5, color = 'red', lw = 2, ls = '-')
ax.plot(x, x + 6, color = 'red', lw = 2, ls = '--')
ax.plot(x, x + 7, color = 'red', lw = 2, ls = '-.')

# custom dash
line, = ax.plot(x, x + 8, color = 'black', lw = 1.5)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length

# possible marker symbols: '+','o','*','s'
ax.plot(x, x + 9, color = 'green', lw = 1, ls = '--', marker = 'o', markersize = 2)
ax.plot(x, x + 10, color = 'green', lw = 1, ls = '--', marker = 'o',
        markersize = 2, markerfacecolor = 'yellow', markeredgecolor = "blue")

# %% [markdown]
# ### Control over axis apperance

# %% [markdown]
# #### plot range

# %%
fig, ax = plt.subplots(1, 3, figsize = (12,4))

ax[0].plot(x, x**2, x, x**3)
ax[0].set_title("default axes ranges")

ax[1].plot(x, x**2, x, x**3)
ax[1].axis('tight')
ax[1].set_title('tight axes')

ax[2].plot(x, x**2, x, x**3)
ax[2].set_xlim([2,5])
ax[2].set_ylim([0,60])
ax[2].set_title("custom axes ranges")

# %% [markdown]
# #### Logarithmic scale

# %%
fig, ax = plt.subplots(1,2, figsize = (10,4))

ax[0].plot(x,x**2, x, np.exp(x))
ax[0].set_title("normal scale")

ax[1].plot(x,x**2, x, np.exp(x))
ax[1].set_yscale("log")
ax[1].set_title("Logarithmic scale(y)")

# %% [markdown]
# ### Placement of ticks and custom tick labels

# %%
fig, ax = plt.subplots(figsize = (10,4))

ax.plot(x, x **2, x, x**3, lw = 2)
ax.set_xticks([1,2,3,4,5])
ax.set_xticklabels([r'$\alpha$', r'$\beta$', r'$\gamma$', r'$\delta$', r'$\epsilon$'], fontsize=18)

yticks = [0, 50, 100, 150]
ax.set_yticks(yticks)
ax.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=18); # use LaTeX formatted labels

# %% [markdown]
# #### Scientific notation

# %%
fig, ax = plt.subplots(1, 1)
      
ax.plot(x, x**2, x, np.exp(x))
ax.set_title("scientific notation")

ax.set_yticks([0, 50, 100, 150])

from matplotlib import ticker
formatter = ticker.ScalarFormatter(useMathText = True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
ax.yaxis.set_major_formatter(formatter)

# %% [markdown]
# ### Axis number and axis label space

# %%
# distance between x and y axis and the numbers on the axes
plt.rcParams['xtick.major.pad'] = 5
plt.rcParams['ytick.major.pad'] = 5

fig, ax = plt.subplots(1, 1)
      
ax.plot(x, x**2, x, np.exp(x))
ax.set_yticks([0, 50, 100, 150])

ax.set_title("label and axis spacing")

# padding between axis label and axis numbers
ax.xaxis.labelpad = 5
ax.yaxis.labelpad = 5

ax.set_xlabel("x")
ax.set_ylabel("y");

# %%
# restore defaults
plt.rcParams['xtick.major.pad'] = 3
plt.rcParams['ytick.major.pad'] = 3

# %% [markdown]
# #### Axis position adjustments

# %%
fig, ax = plt.subplots(1, 1)
      
ax.plot(x, x**2, x, np.exp(x))
ax.set_yticks([0, 50, 100, 150])

ax.set_title("title")
ax.set_xlabel("x")
ax.set_ylabel("y")

fig.subplots_adjust(left=0.2, right=1, bottom=0.1, top=0.9);

# %% [markdown]
# ### Axis grid

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,3))

# default grid appearance
axes[0].plot(x, x**2, x, x**3, lw=2)
axes[0].grid(True)

# custom grid appearance
axes[1].plot(x, x**2, x, x**3, lw=2)
axes[1].grid(color='b', alpha=0.5, linestyle='dashed', linewidth=0.5)

# %% [markdown]
# ### Axis spines

# %%
fig, ax = plt.subplots(figsize=(6,2))

ax.spines['bottom'].set_color('blue')
ax.spines['top'].set_color('blue')

ax.spines['left'].set_color('red')
ax.spines['left'].set_linewidth(2)

# turn off axis spine to the right
ax.spines['right'].set_color("none")
ax.yaxis.tick_left() # only ticks on the left side

# %% [markdown]
# ### Twin axes

# %% [markdown]
# `twinx` and `twiny` function

# %%
fig, ax1 = plt.subplots()

ax1.plot(x, x**2, lw=2, color="blue")
ax1.set_ylabel(r"area $(m^2)$", fontsize=18, color="blue")
for label in ax1.get_yticklabels():
    label.set_color("blue")
    
ax2 = ax1.twinx()
ax2.plot(x, x**3, lw=2, color="red")
ax2.set_ylabel(r"volume $(m^3)$", fontsize=18, color="red")
for label in ax2.get_yticklabels():
    label.set_color("red")

# %% [markdown]
# ### Axes where x and y is zero

# %%
fig, ax = plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0)) # set position of x spine to x=0

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))   # set position of y spine to y=0

xx = np.linspace(-0.75, 1., 100)
ax.plot(xx, xx**3);

# %% [markdown]
# ### Other 2D plot styles

# %%
n = np.array([0,1,2,3,4,5])

# %%
fig, ax = plt.subplots(1, 4, figsize = (12,3))
ax[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))

ax[1].step(n, n**2, lw=2)

ax[2].bar(n, n**2, align = "center", width = 0.5, alpha = 0.5)

ax[3].fill_between(x, x**2, x**3, color = 'green', alpha = 0.5)

# %%
# plot using add_axes and polar projection
fig = plt.figure()
ax = fig.add_axes([0.0,0.0,0.6,0.6], polar = True)
t = np.linspace(0, 2 * np.pi, 100)
ax.plot(t, t, color = 'blue', lw = 3)

# %%
# histogram
n = np.random.randn(100000)
fig, ax = plt.subplots(1,2,figsize=(12,4))

ax[0].hist(n)
ax[0].set_title("Default Histogram")
ax[1].hist(n, cumulative = True, bins = 50)
ax[1].set_title("Cumulative Histogram")

plt.show()

# %% [markdown]
# ### Text annotation

# %%
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)

ax.text(0.15, 0.2, r"$y=x^2$", fontsize=20, color="blue")
ax.text(0.65, 0.1, r"$y=x^3$", fontsize=20, color="green")

# %% [markdown]
# ### Figures with multiple subplots and insets

# %%
fig, ax = plt.subplots(2, 3)
fig.tight_layout()

# %%
fig = plt.figure()
ax1 = plt.subplot2grid((3,3), (0,0), colspan=3)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2)
ax3 = plt.subplot2grid((3,3), (1,2), rowspan=2)
ax4 = plt.subplot2grid((3,3), (2,0))
ax5 = plt.subplot2grid((3,3), (2,1))
fig.tight_layout()

# %%
import matplotlib.gridspec as gridspec
fig = plt.figure()

gs = gridspec.GridSpec(2, 3, height_ratios=[2,1], width_ratios=[1,2,1])
for g in gs:
    ax = fig.add_subplot(g)
    
fig.tight_layout()

# %%
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)
fig.tight_layout()

# inset
inset_ax = fig.add_axes([0.2, 0.55, 0.35, 0.35]) # X, Y, width, height

inset_ax.plot(xx, xx**2, xx, xx**3)
inset_ax.set_title('zoom near origin')

# set axis range
inset_ax.set_xlim(-.2, .2)
inset_ax.set_ylim(-.005, .01)

# set axis tick locations
inset_ax.set_yticks([0, 0.005, 0.01])
inset_ax.set_xticks([-0.1,0,.1]);

# %% [markdown]
# ### Colormap and contour figures

# %%
alpha = 0.7
phi_ext = 2 * np.pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)

# %%
phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

# %% [markdown]
# #### pcolor

# %%
fig, ax = plt.subplots()

p = ax.pcolor(X/(2*np.pi), Y/(2*np.pi), Z, cmap=plt.cm.RdBu, vmin=abs(Z).min(), vmax=abs(Z).max())
cb = fig.colorbar(p, ax=ax)
